# %% [markdown]
# ### Часть 1 - сбор датасета

# %%
# ячейка импортов

! pip3 install requests
! pip3 install beautifulsoup4 
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd

from statistics import mean

from gensim.models.doc2vec import Doc2Vec, TaggedDocument

from sklearn import linear_model
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold, cross_val_score, RepeatedStratifiedKFold
from sklearn import model_selection
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn import metrics

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
russian_stopwords = stopwords.words('russian')

import string
import re
import pymorphy2
# Out:
# Requirement already satisfied: requests in c:\users\marus\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\marus\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marus\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marus\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marus\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: beautifulsoup4 in c:\users\marus\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\marus\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# списки, в которых хранится информация
reviews = []
scores = []
rating_value = []
rating_count = []
year = []
title = []

# %%
# функция, собирающая дополнительную информацию 

def lib_info_add(soup):

# рейтинг книги - общий
    for rat_v in soup.find("span", attrs={'itemprop' : 'ratingValue'}):
        rating_value.append(rat_v.text)

# количество прочитавших
    for rat_c in soup.find("span", attrs={'itemprop' : 'ratingCount'}):
        rating_count.append(rat_c.text)
    
# год выхода
    for ye in soup.find("span", attrs={'itemprop' : 'datePublished'}):
        year.append(ye.text)

# название
    for name in soup.find("span", attrs={'itemprop' : 'name'}):
        title.append(name.text)

# %%
#  функция, забирающая всю нужную информацию

def lib_info(url):
    
    page = rq.get(url) 
    soup = BeautifulSoup(page.text, 'html.parser')
    
    
    for score in soup.find_all("div", class_ = "response-autor-mark"):
        i = len(score.text)
        scores.append(score.text[i-1])
    
    for review in soup.find_all("div", class_ = "response-body-home"):
        reviews.append(review.text)

        lib_info_add(soup)

# %%
# парсинг сайта фантлаба

for i in range(0, 15000):
    url = "https://fantlab.ru/work"+str(i)
    lib_info(url)

# %%
# немного исправить оценки - 0 заменить на 10

marks = scores
for index,item in enumerate(marks):
    if item =='0':
        marks[index] = '10'

# %%
# в некоторых рецензиях нет рейтинга (он не числовой, а 'нет') - заменить его на среднее

numeric_score = []

for i in marks:
    if i.isnumeric() == True:
        numeric_score.append(int(i))

mean_score = int(mean(numeric_score)+0.5)

for index,item in enumerate(marks):
    if item =='т':
        marks[index] = str(mean_score)

# %%
# датафрейм

book_df_add = pd.DataFrame(title)
book_df_add.rename(columns={0:'Names'}, inplace = True)
book_df_add['Average_rating'] = rating_value
book_df_add['Read_by'] = rating_count
book_df_add['Year'] = year
book_df_add['Review'] = reviews
book_df_add['Score'] = marks

# %%
book_df.to_csv('everything_with_clean_values.csv', encoding ="utf-8")

# %% [markdown]
# ### Часть 2 - обработка данных

# %%
# чтобы заново не совершать парсинг, считываю датасет из файла
book_df = pd.read_csv(r"C:\Users\marus\Desktop\everything_with_clean_values.csv", encoding ='utf-8')

# %%
book_df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
book_df["Text"] = book_df.Review.str.lower()

# %%
book_df.Text
# Out:
# 0        \nтот, кто будет читать этот роман как жанрову...
# 1        \nни за что бы не сел за написание отзыва к эт...
# 2        \nдаа, а я уж думал, что я старый, умудренный ...
# 3        \nнаверное, после «гипериона» читать что-то ещ...
# 4        \nроман мне не понравился. с научной фантастик...
#                                ...
# 15674    \nзамечательная идея, интересная!:glasses:врем...
# 15675    \nбиоинженерная мысль приколола, неплохой рома...
# 15676    \nочень не обычный сюжет...\rот этого книгу ещ...
# 15677    \nнеплохой фантастическо-шпионский роман. есть...
# 15678    \nидея живых домов, живых мобилей, живых вещей...
# Name: Text, Length: 15679, dtype: object

# %%
# отбрасываем ненужные символы - цифры, латинские буквы, знаки препинания, 
english = (r'[a-z]+')
digits = (r'\d+')
punctuation = (r'[^\w\s]')
extra = (r'\n?')
symbols = (r'[\n\xa0]')
extra_spaces = (r'\s{2,}')
# мб знаки препинания по-другому?
# word.strip(string.punctuation))

book_df.Text = book_df.Text.str.replace(english, ' ')
book_df.Text = book_df.Text.str.replace(digits, ' ')
book_df.Text = book_df.Text.str.replace(punctuation, ' ')
book_df.Text = book_df.Text.str.replace(extra, '')
book_df.Text = book_df.Text.str.replace(symbols, ' ')
book_df.Text = book_df.Text.str.replace(extra_spaces, ' ')
# Out:
# C:\Users\marus\AppData\Local\Temp/ipykernel_7732/3120310610.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   book_df.Text = book_df.Text.str.replace(english, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_7732/3120310610.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   book_df.Text = book_df.Text.str.replace(digits, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_7732/3120310610.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   book_df.Text = book_df.Text.str.replace(punctuation, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_7732/3120310610.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   book_df.Text = book_df.Text.str.replace(extra, '')
# C:\Users\marus\AppData\Local\Temp/ipykernel_7732/3120310610.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   book_df.Text = book_df.Text.str.replace(symbols, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_7732/3120310610.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   book_df.Text = book_df.Text.str.replace(extra_spaces, ' ')

# %%
book_df.Text
# Out:
# 0        тот кто будет читать этот роман как жанровую ф...
# 1        ни за что бы не сел за написание отзыва к этой...
# 2        даа а я уж думал что я старый умудренный жизне...
# 3        наверное после гипериона читать что то еще в ж...
# 4        роман мне не понравился с научной фантастикой ...
#                                ...
# 16850    совсем не впечатлило там где автор старается б...
# 16851    это книга из серии детская литература после ше...
# 16852    не асилил брал после черного спецназа который ...
# 16853    книга в достаточной степени серая но не совсем...
# 16854    примитивная и пустая пьеса о жизни зеленых и с...
# Name: Text, Length: 16855, dtype: object

# %%
# Лемматизация

morph = pymorphy2.MorphAnalyzer()

# %%
clean_lemmas =[]

# %%
clean_lemmas = []

# %%
for sentence in book_df.Text:
    sent = list(sentence.split())
    sen = []
    for word in sent:
        lemma = morph.parse(word)[0].normal_form
        sen.append(lemma)
    clean_lemmas.append(sen)

# %%
book_df['Lemmas'] = clean_lemmas

# %%
# book_df.Lemmas[15674]
# Out:
# ['замечательный',
#  'идея',
#  'интересный',
#  'временами',
#  'правда',
#  'книга',
#  'нудновата',
#  'продолжение',
#  'читать',
#  'интерес']

# %%
# Убрать стоп-слова

book_df.Lemmas = book_df.Lemmas.apply(lambda x: [item for item in x if item not in russian_stopwords])

# %%
# Смотрим получившийся датасет

book_df
# Out:
#                          Names  Average_rating  Read_by  Year  \
# 0                     Гиперион            8.68     9259  1989
# 1                     Гиперион            8.68     9259  1989
# 2                     Гиперион            8.68     9259  1989
# 3                     Гиперион            8.68     9259  1989
# 4                     Гиперион            8.68     9259  1989
# ...                        ...             ...      ...   ...
# 16850           Чёрный спецназ            6.68       87  2007
# 16851  Планета по имени Тигрис            7.48       31  1984
# 16852           Пульт мертвеца            6.90       75  1988
# 16853          Зелёные и серые            6.23       34  2004
# 16854          Зелёные и серые            6.23       34  2004
#
#                                                   Review  Score  \
# 0      \nТот, кто будет читать этот роман как жанрову...     10
# 1      \nНи за что бы не сел за написание отзыва к эт...      2
# 2      \nДаа, а я уж думал, что я старый, умудренный ...     10
# 3      \nНаверное, после «Гипериона» читать что-то ещ...     10
# 4      \nРоман мне не понравился. С научной фантастик...      6
# ...                                                  ...    ...
# 16850  \nСовсем не впечатлило. Там, где автор старает...      6
# 16851  \nЭто книга из серии «Детская литература». Пос...      6
# 16852  \nне асилил. Брал после Черного Спецназа, кото...      5
# 16853  \nКнига, в достаточной степени серая, но не со...      5
# 16854  \nПримитивная и пустая пьеса о жизни зеленых и...      2
#
#                                                     Text  \
# 0      тот кто будет читать этот роман как жанровую ф...
# 1      ни за что бы не сел за написание отзыва к этой...
# 2      даа а я уж думал что я старый умудренный жизне...
# 3      наверное после гипериона читать что то еще в ж...
# 4      роман мне не понравился с научной фантастикой ...
# ...                                                  ...
# 16850  совсем не впечатлило там где автор старается б...
# 16851  это книга из серии детская литература после ше...
# 16852  не асилил брал после черного спецназа который ...
# 16853  книга в достаточной степени серая но не совсем...
# 16854  примитивная и пустая пьеса о жизни зеленых и с...
#
#                                                   Lemmas
# 0      ['читать', 'роман', 'жанровый', 'фантастика', ...
# 1      ['сесть', 'написание', 'отзыв', 'книга', 'зашк...
# 2      ['даа', 'думать', 'старый', 'умудрить', 'жизне...
# 3      ['наверное', 'гиперион', 'читать', 'ещё', 'жан...
# 4      ['роман', 'понравиться', 'научный', 'фантастик...
# ...                                                  ...
# 16850  ['впечатлить', 'автор', 'стараться', 'серьёзны...
# 16851  ['это', 'книга', 'серия', 'детский', 'литерату...
# 16852  ['асилила', 'брать', 'чёрный', 'спецназ', 'кот...
# 16853  ['книга', 'достаточный', 'степень', 'серый', '...
# 16854  ['примитивный', 'пустой', 'пьеса', 'жизнь', 'з...
#
# [16855 rows x 8 columns]

# %%
# book_df.to_csv('everything_with_clean_values.csv', encoding = 'utf-8')

# %%
# Статистика по классам

classes = pd.value_counts(book_df.Score.values)
classes.plot(kind = 'pie',  autopct='%0.f%%', label = 'Original scores')
# Out:
# <AxesSubplot:ylabel='Original scores'>

# %% [markdown]
# ### Часть 3 - векторизация

# %%
# Шаг 3 - векторизация

input_text = list(book_df.Lemmas.values)
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(input_text)]

# %%
# Применение модели Doc2Vec

model_doc = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)
model_doc.save("model_doc")
vectors = []
for x in documents:
    vec = list(model_doc.dv[x.tags][0])
    vectors.append(vec)

# %%
vectors
# Out:
# [[1.2159346, -1.0169792, -0.57561076, 0.8363148, 0.44855195],
#  [0.5377818, 0.09014924, -0.6659171, 1.4653974, 1.0552458],
#  [0.9477955, 0.17668602, -0.7880299, -0.10854327, 0.09851755],
#  [0.16491058, 0.48486117, -0.5126696, -0.10383299, 0.56541765],
#  [0.49953026, -0.0528485, -0.44248652, 0.21412107, 0.39443865],
#  [1.400876, -0.5617412, -0.62759143, 1.8739742, 0.3948259],
#  [1.1046737, 0.004265965, -0.90760094, 0.022632487, 0.810366],
#  [0.39390346, 0.35600424, -1.276499, 0.7527828, 0.75934714],
#  [0.9152111, 0.398352, -0.39489865, -0.50018567, 0.4612396],
#  [0.46129623, -0.046508722, -1.0045218, 0.29530707, 0.35595524],
#  [0.93264604, 0.8310406, -0.8552428, 0.075003274, 0.49853563],
#  [0.6734577, 0.4714995, -0.84327835, 0.8925873, 1.083742],
#  [0.54122275, 0.2565775, -0.4205959, 0.12911198, 0.8268995],
#  [0.87190515, 0.35798275, -0.50017977, 0.2577943, 0.40605375],
#  [0.100273944, -0.39130652, -0.61777776, -0.18244852, 0.4552069],
#  [1.2441686, 0.61697763, -1.0195912, 2.1417623, 0.54647523],
#  [0.87058675, 0.44531336, -1.3568029, 0.33262172, 1.388718],
#  [0.88288337, -0.10342071, -0.51954967, 0.28264406, 1.3538913],
#  [0.7713906, 0.2262796, -1.2393541, 0.32259524, 0.73877853],
#  [0.48077044, 0.57328004, -0.87451226, 0.13695063, 0.9575273],
#  [0.46536782, 0.4690339, -1.1148695, 0.095505595, 0.46489817],
#  [0.5034886, -0.02795599, -1.2177624, 0.8777134, 1.175545],
#  [0.4579267, 0.25134626, -0.995255, 0.27593088, 0.8487674],
#  [0.63097465, -0.121962145, -1.0007126, 0.29580712, 0.7980174],
#  [1.4632635, 0.47340295, -0.1917197, 0.3551527, 1.0548031],
#  [0.6115023, -0.22563638, -0.93889815, -0.21536757, 1.2672191],
#  [0.23662412, 0.016179074, -1.1516634, 0.22295804, 0.3036635],
#  [0.5035642, -0.039583612, -1.2828677, 1.9320269, 1.0056877],
#  [0.6969105, -0.3624576, -1.0040504, 1.4064453, 1.1799613],
#  [0.18024266, 0.28924572, -1.4646949, 1.1081222, 1.4373488],
#  [1.3713428, 0.6531851, -1.0483483, 0.06890153, 0.84105605],
#  [0.1640254, 0.5458191, -0.9640941, 0.3691962, 0.86049634],
#  [0.701546, -0.3025767, -0.95781624, 0.9202514, 0.8546734],
#  [1.0819489, 0.062468708, -0.49564388, 0.54585814, 0.3767692],
#  [0.61227995, -0.0103791645, -0.9235493, 1.9563389, 0.75608706],
#  [1.1499296, -0.19922368, -1.1742046, 0.00067369593, 0.8113684],
#  [0.7382544, -0.16486727, -1.3919708, 0.8090171, -0.1870749],
#  [0.44271326, -0.2636191, -0.23193315, 0.12543374, 0.50506973],
#  [-0.07272091, 0.10768562, -0.19628417, -0.21234521, 0.11018116],
#  [0.29642314, 0.42560646, -0.18079671, 0.054377075, 0.3398236],
#  [0.3632764, 0.22908062, -0.47784927, -0.196874, 0.32667983],
#  [0.3017069, -0.10637081, -0.18396074, -0.09030897, 0.10582316],
#  [-0.020932648, 0.06758007, -0.20605591, -0.05441986, 0.036663104],
#  [0.3010018, 0.19684272, -0.42528394, -0.018811878, 0.12461548],
#  [1.1621184, -1.0992566, -0.8849054, 1.8564138, 1.5785425],
#  [0.7499905, 0.24380134, -0.62135035, 0.2605106, 0.2501255],
#  [0.7080064, 1.1290497, -1.2478471, 0.30650267, 0.83736056],
#  [0.5654688, 0.04911124, -0.7936883, -0.02540801, 0.3992087],
#  [0.6461362, 0.40918887, -0.49871317, -0.015733238, 0.5232989],
#  [1.3235334, 0.042833265, -0.93715644, 0.1328429, 0.73232156],
#  [0.47119427, 0.22585343, -1.140448, -0.25056002, 0.5129786],
#  [1.8517132, 0.6341735, -0.28181776, -0.5792105, 0.5135111],
#  [0.81706005, 0.66343504, -0.41007057, 1.3077534, 1.8574892],
#  [1.2996197, 0.8934997, -0.7368393, -0.021822965, -0.0890182],
#  [0.21172, 0.7854549, -2.2368076, 0.65655, 1.1815556],
#  [1.2886487, 2.1209671, -2.8299224, -0.55826575, 1.1191647],
#  [0.114167355, -0.15984443, -1.7147343, 0.75546104, 0.7082654],
#  [0.05911525, -0.09814898, -0.47779498, -0.24712276, 0.22569028],
#  [0.3047234, -0.5888602, -1.3396826, 0.8223791, 1.234436],
#  [0.5546935, -0.5750099, -0.79798806, 0.31992668, 1.2887003],
#  [0.4818569, 0.12295749, -0.7530666, -0.016417794, 0.49783498],
#  [0.45621467, 0.3202229, -0.480042, -0.48246908, 0.28176776],
#  [0.43690985, -0.048330538, -0.117907725, -0.03277902, 0.024166236],
#  [0.38557017, 0.029560674, 0.007350448, -0.15271491, 0.20610662],
#  [0.7343527, -0.14198062, -0.19832732, 0.037781365, 0.19624643],
#  [0.3842695, -0.27204973, -0.5265436, 0.16209315, 0.46472213],
#  [0.406177, 0.116609134, -0.4896639, -0.11245998, 0.28482234],
#  [-0.05661173, -0.13080628, -0.12091286, -0.039691783, 0.3319154],
#  [0.09518317, -0.040717266, 0.012052802, 0.03614477, 0.06746591],
#  [0.22270548, 0.17631787, 0.070936814, -0.028810613, 0.182598],
#  [0.42202726, -0.15100218, -0.46390748, 0.05898602, 0.20776801],
#  [0.26734278, 0.07750905, -0.2152834, -0.08362384, 0.2036559],
#  [0.0925576, 0.13150248, -0.17922346, 0.068813846, 0.12177785],
#  [0.47719213, -0.2643414, -0.29189473, 0.14926179, 0.41896164],
#  [1.5287281, -0.19046567, -0.06690215, 0.31874743, 0.8315944],
#  [0.39315, 0.0061175097, -0.16229488, 0.23364651, 0.4828687],
#  [0.22396903, -0.026526785, -0.18637905, -0.13960667, 0.28048778],
#  [0.26967564, -0.30688027, -0.08266114, 0.34856972, 0.1088696],
#  [1.1667608, 0.25725144, -0.568669, -0.01766077, 0.044545133],
#  [1.2251878, -0.21941242, -0.54955703, 1.3905598, 0.69707847],
#  [0.38118172, 0.21488334, -0.9534674, 1.6665326, 1.3400205],
#  [0.9835748, 0.978258, -0.33897376, 1.4846919, 0.8535066],
#  [1.2817112, -0.30426618, -0.7194359, 1.6760497, 0.6741169],
#  [0.6728311, 1.0061336, -0.771724, 0.6318465, 1.402012],
#  [1.2474498, 0.05835053, -0.102262236, 1.2730908, 0.7353851],
#  [0.3250261, -0.11823303, -0.1441302, -0.04511424, 0.2102033],
#  [0.1611088, 0.5582837, -0.22067803, 0.85649705, 1.4895926],
#  [0.64043, 0.50000167, 0.5277845, 0.57033294, 0.5909275],
#  [1.0951732, -0.9427917, -1.2537087, 0.065056175, 0.8854031],
#  [0.32583055, -0.12523381, -0.8402524, 0.3549629, 0.23920643],
#  [0.23263007, -0.072872, -0.33817127, -0.3102237, 0.2594827],
#  [1.8620815, -0.007957649, -0.4682708, -0.27388045, 0.6184539],
#  [0.51515555, -0.61350054, -0.5273737, 0.003131038, 0.7397852],
#  [0.16691884, 0.2008228, -0.29607278, -0.112509355, 0.035850327],
#  [1.80298, -0.9577336, -0.80774957, 0.16446798, 1.0722107],
#  [0.31362784, -0.15923324, -0.28858784, -0.06870149, 0.14570923],
#  [0.20532535, -0.21895799, -0.4189754, 0.12030288, 0.21064532],
#  [0.5312169, -0.43403935, -0.112308614, 0.43823013, 0.4659872],
#  [0.4712682, -0.34839576, -0.6956925, 1.060512, 0.5742184],
#  [0.6078318, -0.3251516, 0.03479608, 0.6890666, 0.3136839],
#  [0.27836218, 0.15523009, 0.06783485, -0.10008031, 0.34593996],
#  [0.13667369, 0.19635366, -0.0360594, -0.043049198, 0.1724273],
#  [0.1884921, 0.12716432, 0.03935913, 0.29631907, 0.35018948],
#  [0.19458741, -0.120638594, -0.6157587, -0.062377367, 0.7463609],
#  [1.585306, -1.1291451, -0.54583734, 0.22796658, 0.4171779],
#  [1.0360265, -0.7976271, -0.4164554, 0.6177989, 1.3492366],
#  [0.32175532, -0.014481865, -0.3829489, -0.6697018, 0.37868616],
#  [0.76983654, 0.047741212, -0.1927132, -0.03971395, 0.35066685],
#  [-0.02612939, 0.16015716, 0.087202206, 0.0034715296, 0.30963466],
#  [0.947392, -0.3777973, -0.124209344, 0.8267645, 0.7147804],
#  [0.581178, -0.018537108, 0.12946928, 0.5634269, 0.38835534],
#  [-0.04582164, 0.09461487, -0.04923413, 0.03310316, 0.22228299],
#  [0.346566, -0.21826874, -0.015106063, -0.08016734, 0.25574496],
#  [0.3796554, -0.57217973, -0.22186235, 0.09750655, 0.52663285],
#  [0.44031677, -0.19877927, -0.19185662, 0.16281942, 0.49158072],
#  [0.24571943, -0.16219296, -0.19694273, 0.05389321, 0.6498392],
#  [0.18304764, -0.11297138, -0.073764354, 0.31106082, 0.2280955],
#  [0.12371815, -0.099353954, 0.0058881724, -0.15936925, 0.26238886],
#  [0.11359184, 0.11365323, -0.023647722, 0.07054592, -0.11340385],
#  [1.0621595, -0.9267734, -0.94799167, 0.30833843, 0.69436204],
#  [1.6330324, -0.083084576, -1.4474504, -0.66074884, 0.74926245],
#  [0.36435044, -0.25949374, -0.19354315, -0.08169739, 0.062160697],
#  [0.3859999, 0.017637985, -0.11896799, -0.3004323, 0.26798093],
#  [0.26152605, 0.019214146, -0.09952963, 0.048322726, 0.25591326],
#  [0.7752459, 0.49957, -0.4073003, -0.2555676, 0.1358347],
#  [0.28260937, 0.007026185, -0.32708365, 0.60372424, 0.36267263],
#  [0.4868218, 0.14538702, -0.14604753, 0.22847879, 0.1532675],
#  [0.09432486, 0.049552094, -0.0023921074, 0.07952192, -0.10084486],
#  [0.091375045, 0.04201868, -0.06651928, -0.087974384, 0.03536316],
#  [1.7076553, -0.3352379, -0.49002317, -0.21465552, 0.51825345],
#  [0.6582684, 0.1621212, -0.49854612, 0.022262413, 0.5284849],
#  [0.7663417, -0.27233866, -0.23404557, 0.46089953, 1.4073447],
#  [0.22625645, 0.12497269, 0.06720168, 0.2980403, 0.15377718],
#  [1.2289119, 0.18934213, -0.7066279, 1.0328048, 0.9755052],
#  [0.6425673, -0.18200184, -0.41674143, 0.06643829, 0.43668956],
#  [0.7815594, 0.2058371, -0.5213795, 0.0887195, 1.1708558],
#  [0.8299657, -0.04413244, -0.28189698, 0.38023558, 0.55368924],
#  [0.50216156, -0.014819717, -0.041714378, -0.03701468, 0.17092851],
#  [0.587261, -0.3098588, -0.8227122, 0.92615885, 0.59068495],
#  [0.8909956, -0.24491818, -0.46991155, 0.7392651, 0.5295855],
#  [0.13824007, 0.22243468, -0.3721413, 0.17651767, 0.13832563],
#  [0.3728204, 0.17803408, -0.3088521, -0.21995914, 0.13945001],
#  [0.40312916, 0.18050702, -0.06000011, -0.07741598, 0.29325587],
#  [0.48675126, 0.072306514, -0.15603425, 0.08447204, 0.20171462],
#  [0.4281686, -0.11803411, -0.18674505, -0.21615633, -0.0930104],
#  [0.44935977, -0.29126644, -0.17929825, -0.1789668, 0.43671557],
#  [1.3534509, 0.08009632, -0.16287057, -0.11428718, 0.64699],
#  [0.27815825, 0.09496125, -0.76183164, -0.31332487, 0.7882921],
#  [0.6056146, -0.55147356, -0.39393562, -0.121903434, 0.26233247],
#  [1.0429629, -0.1638277, 0.19357565, 0.62223786, 1.7086544],
#  [1.5245209, -0.6421527, -0.8221459, 0.8574029, 0.86430526],
#  [0.21065998, -0.0040506283, 0.03445648, -0.033914138, -0.03042453],
#  [0.8180503, -0.30356216, -0.872464, -0.3998318, 0.654443],
#  [1.074366, -0.64128387, -0.36080924, 1.1316247, 0.8517094],
#  [0.35697827, -0.52307385, -1.217945, 1.006846, 1.3557947],
#  [0.8882076, 0.023645865, -0.37514317, 0.43426567, 0.4253746],
#  [0.43943918, -0.03594915, -0.5419662, -0.30963302, 0.26832005],
#  [1.0912515, 0.8974822, -0.76003045, -0.3054566, 0.51211905],
#  [0.96700007, 0.26928118, -0.27141038, 0.0040247766, 0.2351098],
#  [0.50626415, -0.19716577, -0.66776836, 0.043465875, 0.45477358],
#  [0.6181943, -0.17379571, -0.8721096, 0.10715928, 0.35581547],
#  [1.033081, 0.83913356, -0.97506624, 0.3789738, -0.033579335],
#  [0.5299846, 0.21952742, -0.92946523, 1.8069353, 0.3508994],
#  [0.3664728, -0.28414008, 0.020797303, -0.29029903, 0.8893727],
#  [0.43749928, -0.15731439, -0.50062764, -0.0075451257, 0.36602262],
#  [1.2117646, -0.7669285, -0.21559936, 0.010335963, 1.0712651],
#  [0.7746127, -0.014870321, -0.32536048, 0.48864964, -0.009121328],
#  [0.36618376, 0.12356219, 0.15874241, 0.122848816, 0.57996017],
#  [0.14895698, -0.048289064, -0.3721822, -0.0022749593, 0.40671054],
#  [0.16187243, -0.16545005, -0.68421733, -0.34688845, 0.17394266],
#  [0.17486873, -0.6522105, -0.4415991, 3.1205804, 2.1551483],
#  [1.0364047, -0.1687385, -0.7084206, 1.4814545, 0.41027084],
#  [1.026697, -0.3086486, -0.5780931, 1.07327, 0.46371147],
#  [0.017555373, 0.2720216, 0.24971285, -0.17611605, 0.34952688],
#  [0.62785137, -0.07570755, -0.46270463, -0.40706885, 0.46424147],
#  [0.7988788, -0.26611397, -0.30775574, 0.92457795, 1.428664],
#  [0.28957233, -0.09269597, -0.08725054, -0.09578296, 0.38760173],
#  [0.9239792, 0.52698654, -0.71195793, 0.41552547, 0.49411002],
#  [0.2345486, -0.72043085, -0.95878506, 1.0382428, 1.1330755],
#  [1.4013087, 0.37847865, -0.34500748, 0.90641564, 0.540289],
#  [0.8836571, -0.16750224, -0.90166074, -0.003606797, 0.28078902],
#  [0.74158907, -0.36752716, -0.11447145, 0.0636302, 0.27554652],
#  [0.2512752, 0.16589314, -0.091640525, -0.13941613, 0.123915404],
#  [0.10003182, -0.031507522, -0.2644573, -0.28452152, 0.3153503],
#  [-0.059366927, 0.0077963388, 0.015684906, -0.16861154, -0.09014421],
#  [0.5549913, -0.050676014, -0.50686383, 0.23678505, 0.82996356],
#  [0.17776321, -0.29800805, -0.47281072, 0.12363358, 0.38378966],
#  [0.4594431, 0.083574064, -0.35307696, -0.009851875, -0.1248476],
#  [-0.15985882, -0.10158717, -0.10462647, 0.31918526, 0.18881437],
#  [1.0548816, -0.4795051, -0.82878727, 0.30381894, 0.40981814],
#  [0.4455553, -0.34828034, -0.35690612, 0.26003218, 0.24988785],
#  [0.10863946, -0.06305803, -0.07313547, -0.0016632443, 0.017737592],
#  [0.3500114, -0.12896498, -0.32957545, 0.06767744, 0.0715741],
#  [0.51634383, -0.5428508, -0.49727672, -0.0043520546, 0.6001721],
#  [0.3080458, 0.2884703, -0.25878435, 0.027073536, -0.14428642],
#  [0.14577796, -0.13036995, -0.23532403, -0.028639697, 0.47715664],
#  [0.16397281, -0.066539474, -0.2954714, 0.029347261, 0.37375984],
#  [0.46352172, -0.23903085, -0.0863941, 0.12768911, 0.23419447],
#  [0.11410824, 0.05869962, -0.03847189, 0.12514965, 0.06839946],
#  [0.50299877, -0.41505197, 0.06590973, 0.37670952, 1.3257288],
#  [1.1060514, 0.09442434, -0.7257374, 0.09906397, 0.7714808],
#  [0.9790654, -0.08499094, -0.21280742, 0.17975526, 0.29179314],
#  [0.35287616, 0.041915245, -0.37403086, 0.027994238, 0.17641522],
#  [0.5638806, 0.046402175, -0.779178, -0.6290022, 1.0597739],
#  [0.72338724, -0.03164315, -0.6396813, 0.35633758, 0.41043666],
#  [0.48053902, 0.28671584, -0.11742064, -0.6745594, 0.35686496],
#  [0.28716567, -0.0618695, -0.14762333, -0.017859293, 0.07813261],
#  [0.6180928, -0.09145149, -0.27684787, 0.47710517, 0.5993187],
#  [0.51181054, -0.0744059, -0.21101087, 0.04617911, 0.22868185],
#  [0.53075767, 0.16077943, -0.36864763, -0.1634232, 0.39007133],
#  [0.26096937, -0.2764406, -0.36932254, 0.19724841, 0.2687642],
#  [0.9091533, -0.3209989, -0.70412797, -0.15962222, 0.27680534],
#  [0.61832374, -0.06966617, -0.562014, 0.0019502053, 0.6804604],
#  [0.37913328, 0.2024556, 0.18101993, 0.3903889, 0.060640123],
#  [0.3316339, 0.0826683, 0.08048099, 0.045321282, 0.11282584],
#  [0.45034504, 0.1994624, -0.038413472, 0.11021804, 0.6702274],
#  [0.6185064, -0.5376015, -0.57134235, 0.3162743, 1.1214049],
#  [1.1144446, -0.17209594, -0.10463129, 0.2259145, 0.5308883],
#  [0.36898857, -0.3266188, -0.52612, 0.5632503, 0.6872084],
#  [0.5942604, 0.14533633, -0.62362856, 0.14898445, 0.03935415],
#  [0.06916482, 0.36787876, 0.02138633, -0.08799562, 0.14104527],
#  [-0.07191002, 0.08576296, -0.16257755, 0.26481363, 0.13335712],
#  [1.0272669, -0.011278501, -0.6748858, 0.22553486, 0.375143],
#  [0.74331915, -0.13639571, -0.30641174, -0.32922158, 0.50374067],
#  [0.54040194, -0.0264576, -0.5166827, -0.2774676, 0.26648238],
#  [0.37088004, -0.1719241, -0.10299807, 0.0800527, 0.3136552],
#  [0.51411635, 0.2790894, -0.20890023, -0.24082206, 0.590297],
#  [0.7042662, -0.29327604, -0.7638607, 0.12963094, 0.5356882],
#  [1.3780228, -0.58103645, -0.6922385, 0.7588025, 0.48983294],
#  [0.4473865, -0.0625203, -0.16657712, 0.5048429, 0.30812365],
#  [0.43930024, 0.2816829, -0.53057, -0.40866154, 0.8848525],
#  [1.1774694, -0.19685061, -0.29579782, 0.32570338, 0.9341138],
#  [1.05436, -0.040955804, 0.04566037, 0.664579, 0.8863228],
#  [0.4890598, -0.4068498, -0.6588708, -0.4163318, 0.19016261],
#  [0.5743097, -0.27146384, -0.27624032, 0.124302775, 0.4755163],
#  [0.25670832, 0.13882445, 0.025668206, -0.0023624625, 0.015448116],
#  [0.87123746, 0.044605915, -0.7468001, -0.2369828, 0.6030319],
#  [1.1906017, -0.010647573, -0.3108182, 0.47804415, 0.7706633],
#  [1.0878149, 0.08222228, -0.2961172, 0.72307396, 0.8331335],
#  [0.7264887, -0.08527935, -0.13904622, 0.286698, 0.37368372],
#  [1.3108633, -0.26581293, -0.21674968, 0.2657501, 0.43155232],
#  [0.74325, -0.27415827, -0.20234656, 0.24129958, 0.2389331],
#  [0.29742238, 0.19173993, -0.05283497, -0.10887232, 0.49881446],
#  [0.40852478, -0.13710755, 0.06942462, 0.15707238, 0.5071336],
#  [0.12498599, -0.03467295, -0.38394433, 0.058531623, -0.05548437],
#  [0.29159033, 0.04813381, -0.3673266, -0.089075655, 0.19969915],
#  [0.9729266, 0.35129473, -0.9480801, -0.031356834, 0.23050947],
#  [0.47854155, -0.21297953, -0.4638716, 0.43535426, 0.3267767],
#  [1.4305129, 0.04424325, -0.6626207, 0.43988508, 1.0316396],
#  [0.32296392, -0.108354665, -0.42843983, 0.014925953, 0.05528375],
#  [0.43994987, 0.16793863, -0.72563934, 0.77283424, 0.5778179],
#  [0.3555728, 0.35384658, -0.8929284, 0.67189604, 0.8921089],
#  [0.44132516, 0.25057045, -0.008008703, 0.45702782, 0.7319136],
#  [0.37393725, 0.14204594, -0.30963722, 0.43495932, 0.7482253],
#  [1.0150093, -0.04859083, -0.771283, 0.7611967, 0.4639109],
#  [0.45454574, 0.19327484, -0.27510935, 0.1702595, 0.47832018],
#  [0.61746854, 0.2841128, -1.658523, 0.5215663, 0.38598207],
#  [0.6915036, 0.24719764, -1.2899595, 0.8248632, 0.47862947],
#  [0.91693103, 0.30676425, -0.69785136, -0.4176613, 0.56315017],
#  [0.101426765, 0.05733454, -0.23642352, 0.3820554, 0.1851774],
#  [0.56622654, 0.0859126, -0.47468454, 0.10063872, 0.49964446],
#  [0.75672835, 0.7087526, 0.08302694, 0.8252677, 2.0089812],
#  [0.5968336, 0.046894956, -0.33156228, 1.0251658, 1.0436686],
#  [-0.06400341, 0.41541272, -0.85575676, 0.23324712, 0.6787791],
#  [0.5772033, 0.72279125, -0.6023473, 2.2719183, 1.6237258],
#  [0.46545753, 0.7990669, -0.11699483, 0.99372387, 1.3848469],
#  [0.43597534, -0.35046583, -0.6185507, -0.12073593, 0.49144465],
#  [0.784551, 0.8944496, -0.39184734, 1.0535043, 1.7737398],
#  [0.6041038, 0.20442486, -0.5447707, 0.26198208, 0.7680445],
#  [0.15077895, 0.16313124, -0.21133478, -0.048390973, -0.002721347],
#  [0.37373164, 0.403412, -0.29070315, 0.8684437, 0.25621969],
#  [0.15024754, -0.045835007, -0.033048123, -0.050098207, 0.2786817],
#  [0.4914545, 0.10317419, -1.6234459, 0.78705627, 1.3783867],
#  [0.50929147, 0.41296494, -0.14561397, 0.49543443, 0.35927537],
#  [0.081192896, 0.07512517, -0.5220949, -0.22774239, 0.43344733],
#  [0.8830015, 0.18871154, 0.15914637, 0.7960395, 1.0977347],
#  [0.4151157, -0.45332822, -0.50789136, 0.23480116, 0.4025274],
#  [0.20086363, 0.9798528, -0.77148974, 0.74015504, 0.97935474],
#  [0.79996276, -0.22286814, -0.7349888, 0.40805143, 0.53688514],
#  [0.6641489, 0.31505805, -0.18801877, -0.2658002, 0.68607134],
#  [1.3647537, 0.29576734, -0.7081891, 0.34499535, 0.51167935],
#  [0.82834053, -0.07369901, -0.6524373, -0.003810438, 0.63544697],
#  [0.7844453, 0.13074048, -0.5064024, 0.100927934, 0.43845916],
#  [0.53090984, 0.11253061, -0.25311667, 0.13340414, 0.10960051],
#  [0.302009, 0.25909936, -0.025334412, -0.056908883, 0.20589332],
#  [1.0198512, 0.59179145, -0.46535903, 0.07943428, 0.07004499],
#  [0.6823591, -0.046354815, -0.26712552, 0.41579306, 0.5741556],
#  [0.6286778, 0.32817906, -0.69189185, 0.69582045, 0.58960086],
#  [1.5848229, -0.31656414, -0.48595554, 0.8209347, 0.42067784],
#  [0.54015887, -0.23685856, -0.50974876, 0.26475132, 0.63105893],
#  [0.71795255, 0.53358555, -0.9269984, 0.77131474, 0.68377423],
#  [1.8039124, -0.09981825, -1.079014, -0.1785739, 0.21194105],
#  [0.33726722, -0.030770577, -0.41514996, -0.02120358, 0.29855013],
#  [0.3712745, -0.12060067, -0.5717814, 0.14857581, 0.6918523],
#  [0.2828403, 0.0736018, -0.14553916, 0.06032526, 0.7327753],
#  [0.92500407, 0.06465015, -0.25517672, 0.21277435, 0.66223353],
#  [0.21722698, 0.04484761, -0.4719062, 0.29147416, 0.5914558],
#  [0.40235904, -0.052518014, -0.14355561, 0.07717745, 0.9529886],
#  [0.72286457, 0.27883822, -0.28543252, 0.20088832, 0.05273245],
#  [1.8898661, -0.06796746, 0.01407578, -0.51922995, 1.2942423],
#  [0.9287303, 0.032888584, -0.089458875, 0.5809589, 0.38935137],
#  [1.6615835, 0.79399186, -0.104427576, -0.45378518, 0.95708174],
#  [0.96718824, 0.9376416, -0.73706263, 1.4236048, 0.67956233],
#  [0.484698, 0.80065644, 0.16921665, 1.0831383, 0.8007208],
#  [0.31689665, 0.2156015, -0.09214382, 0.4396181, 0.34499526],
#  [0.47412536, 0.38728097, -0.46413976, -0.16272646, 0.06398557],
#  [0.753198, 0.07223175, -0.48561552, -0.16930488, 0.66224486],
#  [0.68296003, -0.18549727, -0.6728053, 0.7187545, 0.75278467],
#  [0.26525074, -0.35857666, 0.013764115, 0.6687162, 0.99377996],
#  [1.5266114, -0.42931727, -0.43039298, 0.37973294, 0.4582042],
#  [0.28066304, -0.07777807, -0.10250821, 0.38256732, 0.75842446],
#  [0.7134398, 0.014562055, -0.6910061, 0.21482469, 0.19727907],
#  [0.20546229, 0.10045616, -0.19130984, 0.063260645, 0.3157661],
#  [0.5693782, -0.15259093, -0.48241767, 0.3639754, 0.22380957],
#  [0.30400822, 0.1853752, -0.31001946, -0.29695266, 0.2932579],
#  [0.2684425, -0.501682, -0.42727688, 0.11969591, 0.30153045],
#  [0.2850444, -0.11801986, -0.39863166, -0.0981484, 0.45967045],
#  [-0.12530795, 0.2794129, -0.34382138, 0.3309989, -0.043522984],
#  [1.2705939, 0.01241717, -0.75884426, 0.8473584, 0.5363139],
#  [0.18519256, 0.2715386, -0.2044803, -0.20283763, 0.41747904],
#  [0.32485032, 0.065999255, -0.16425726, -0.035290588, 0.70420164],
#  [0.04981361, 0.029817017, 0.20106293, 0.30675238, 0.609576],
#  [0.77305967, -0.17532167, -0.62701803, -0.26574045, 0.63306856],
#  [0.5801547, -0.1926886, -0.19844426, 0.13515565, 0.33900973],
#  [0.17860626, -0.063204415, -0.40697843, 0.05371322, 0.1533954],
#  [0.12828778, -0.00981504, -0.58567274, 0.17232849, 0.31587574],
#  [1.4909126, 0.5934363, -0.55624187, -0.2612574, 0.07328675],
#  [0.96196026, 0.26946408, -0.3248237, -0.52191097, 1.1939598],
#  [0.6731024, 0.14134602, -0.3559849, -0.022735348, 0.04141754],
#  [0.4795416, -0.02613794, -0.1040926, -0.37005422, 0.32155684],
#  [0.65205157, -0.19856466, -0.65471596, 0.7117248, 0.3884953],
#  [0.78335845, 0.0014030403, -0.3880679, -0.3018263, 0.20162497],
#  [0.3102862, 0.4341096, 0.015030068, 0.23103209, 0.49033576],
#  [0.9421047, -0.26654646, -0.23966707, -0.06288398, 0.4489554],
#  [-0.2700915, -0.08014727, -0.37960035, -0.088391, 0.51546794],
#  [0.3676813, 0.17057632, -0.02835353, -0.02168911, 0.07403453],
#  [0.45932224, 0.07885703, -0.40703, 0.61039037, 0.71066755],
#  [0.5087727, 0.11107579, -0.00057678967, -0.09607395, 0.26411322],
#  [0.4260733, 0.002184875, -0.40856054, 0.20316896, 0.6441605],
#  [0.36725622, 0.061718013, -0.41542745, 0.42330277, 0.30653936],
#  [0.4246895, 0.41698876, -0.40257367, 0.8578794, 0.52248883],
#  [1.9833049, 0.21892844, -0.99996597, 1.07134, 0.033101603],
#  [0.54042536, 0.15691687, -0.17749938, 0.7590949, 0.46253812],
#  [0.6637731, 0.40627977, -0.80343795, 0.3156509, 0.18021066],
#  [1.2750695, 0.004729808, -0.6821079, 0.8068463, 0.3059263],
#  [0.26181602, -0.13566251, -0.036140352, 0.4593845, 0.073351786],
#  [0.4411824, 0.13885492, -0.01941179, 0.10309392, 0.39905456],
#  [0.347248, 0.122783795, -0.24145459, 0.07575953, 0.5565933],
#  [0.6244201, -0.33787957, -0.32713372, 0.043469936, 0.07405888],
#  [-0.055493213, 0.11957543, -0.30497453, -0.2359864, 0.69903725],
#  [0.07822206, 0.109797895, -0.46595892, -0.22600915, 0.20325194],
#  [0.28231063, -0.0076716198, -0.6045952, 0.41745853, 1.2773807],
#  [0.4460282, 0.2519313, -0.7722415, 0.7981406, 0.37089],
#  [0.51665294, 0.05830092, -0.23988359, 0.47646636, 0.422502],
#  [0.8071232, 0.11937905, -0.30146924, 0.9757397, 0.48863998],
#  [0.5256616, 0.41152748, -0.55745447, 0.25831994, 0.76141214],
#  [0.440808, 0.14198385, -0.02956872, 0.3657104, 0.29167372],
#  [-0.14183173, -0.5303782, -0.6134699, -0.14261337, 0.060350366],
#  [0.24456112, 0.120803915, -0.07464427, 0.44505474, 0.36848274],
#  [0.176239, 0.27917522, -0.10279214, 0.18336016, 0.27943033],
#  [0.16256352, 0.009237784, -0.3697377, -0.062085453, 0.14975882],
#  [0.1375083, -0.047416627, -0.25564238, 0.0052002193, 0.21611513],
#  [0.3395856, 0.20684043, -0.17906465, 0.18181823, 0.42297056],
#  [0.37485534, 0.21978496, -0.052511208, 0.0075344164, 0.46322975],
#  [0.5840138, 0.37647715, -0.4034526, 0.39160967, 0.493943],
#  [0.38264707, 0.2913013, 0.0069252606, 0.53110397, 0.09781033],
#  [1.3332703, 0.51864874, -0.38444728, 0.74117154, 1.1835382],
#  [1.9718012, -6.187399e-05, -0.35484406, 1.9762948, 0.057052743],
#  [0.7946675, 0.14834231, -0.23447482, 0.17496404, 0.7619452],
#  [1.8620408, 0.2155064, -0.8204997, 1.0095544, -0.1270943],
#  [2.7424595, 0.46538213, -0.16570306, 0.64724064, 0.30545667],
#  [1.9168509, 0.8804904, -0.020986969, 1.9026692, 0.7525245],
#  [1.1214736, 0.08929509, -0.032240372, 1.4323875, 0.70151865],
#  [2.0001907, 0.47120634, -1.1963255, 0.020416616, -0.08862313],
#  [0.7245945, 0.34875244, -1.2607908, 0.2836803, 1.1319823],
#  [1.3374299, -0.17094474, -0.780389, 1.6379615, 1.1599851],
#  [1.5652696, 0.61091655, 0.021351412, 1.3343549, 1.1704808],
#  [1.5757827, 0.6282771, -1.0918806, -0.09174894, 0.6461947],
#  [1.5412412, 0.5579717, -0.6434369, 0.72426707, 0.5940425],
#  [0.76548135, 0.041206945, -0.7805377, 0.43239164, 1.3941782],
#  [0.13936903, 0.043746874, -0.23629853, 0.08261919, 0.6141776],
#  [0.95394766, 0.16202421, -0.68584496, 1.9004002, 1.2398239],
#  [0.4580639, -0.00507386, 0.03685337, 0.14297402, 0.74022275],
#  [0.6313697, 0.27454782, -0.8726415, 0.75409156, 1.2661005],
#  [1.3345909, 0.36888427, -0.21531479, 1.0791824, 1.035244],
#  [2.6076298, 0.9203503, 0.6124908, -0.19725405, 1.277738],
#  [0.32595286, 0.38196066, -0.2618444, 0.17506978, 0.5372994],
#  [1.2638552, 0.22076866, -0.3702004, 1.200724, 0.6389349],
#  [0.3738832, 0.4298435, -0.4450406, 0.3307585, 0.1877177],
#  [1.244053, 0.20362906, -0.6308491, 0.9904548, 0.46217662],
#  [0.9393588, -0.5128288, -0.63753915, 0.12668523, 0.27088618],
#  [1.4509608, -0.31791037, -0.37935436, 1.0636497, 0.6653019],
#  [1.2081634, 0.1701294, -0.43022534, 0.8985543, 0.60833734],
#  [2.275257, 0.07157801, -0.41838235, 1.0467892, 0.3535871],
#  [0.9533871, 0.032914918, -0.6549201, 0.1806568, 0.57953584],
#  [0.8112767, -0.19298565, -0.7829954, 0.20819744, 0.7542202],
#  [1.664276, 0.76258427, -1.6652691, -0.87399787, 0.1539685],
#  [2.2304966, 0.2046594, -0.8359533, 0.40351614, -0.12749386],
#  [-0.0372719, 0.12637804, -0.06432534, -0.089808635, 0.07566896],
#  [0.58153206, 0.346701, -0.79264915, -0.2633911, 0.90454817],
#  [1.0223328, 0.46279112, -0.55493104, -0.2659241, 0.41076437],
#  [0.4365562, 0.18490323, -0.4603875, 0.78186256, 1.1254326],
#  [1.2706987, 0.2674481, -1.0135666, 0.13746208, 0.49048892],
#  [0.8131835, 0.70246786, -0.6046997, 1.0504206, 0.97366154],
#  [0.6835996, 0.12235814, -0.5539226, 0.1373164, 0.7574126],
#  [0.82293177, -0.18507142, -0.73990655, 1.13268, 0.75039226],
#  [0.42269748, 0.11955621, -0.2152657, 0.38233194, 0.4550247],
#  [1.5878507, -0.022543505, -1.4775236, 0.3553966, 0.0131436],
#  [0.34053782, 0.4793748, -0.8632275, 0.29262227, 0.58460975],
#  [1.2560617, 0.028680038, -1.0381451, 0.37570426, 1.025352],
#  [0.7026775, 0.45317715, -0.8063159, 0.114841014, 0.8077166],
#  [1.0293441, 0.5762705, -0.83746374, 0.30669498, 0.37780404],
#  [0.02917749, 0.030524867, -0.40725473, -0.06322287, 0.5419672],
#  [2.0609443, 0.2617504, -1.0874951, 0.4535503, 0.489551],
#  [1.2620882, 0.53303, -0.35638422, 1.3595545, 0.7398223],
#  [1.4435009, 0.87050784, -0.29633874, 0.44489732, 0.58197355],
#  [0.82585305, 0.48358056, -0.8222501, 1.5289851, 1.2029562],
#  [0.62890273, 0.5266736, -1.2464056, 0.15519196, 0.8174978],
#  [0.1291648, 0.412957, -0.6045824, 0.15485592, 0.61369973],
#  [0.8468836, 0.31108764, -0.32962215, 0.84416544, 1.0659691],
#  [1.0665535, 0.5754284, -0.32575342, 0.22964261, 0.9041735],
#  [3.0159621, 1.7142264, -0.70586157, 1.4759371, -0.2740824],
#  [1.237024, 0.14353429, -0.7572264, 1.4877102, 1.1321939],
#  [0.74001735, 0.06666631, -0.7805394, -0.02867231, 0.7648221],
#  [0.46931645, -0.2267642, -1.2378393, 1.7803687, 1.6151872],
#  [0.9318941, 0.18986596, -0.7663384, 0.1974512, 0.39541274],
#  [1.1766922, 0.49091, -1.1846662, 0.6636669, 1.1702825],
#  [1.2829036, 0.9882384, -1.2839485, 0.75827265, 1.2061126],
#  [1.3344691, 0.69994706, -0.082175285, 0.10406441, 1.136974],
#  [1.4559536, 0.8522741, -1.1605755, 0.5306228, 0.8972613],
#  [0.86538374, -0.5431233, -0.90427274, 0.013540975, 0.46870643],
#  [0.21355624, 0.32507256, -0.7353512, 0.6264773, 0.44097924],
#  [0.40502, 0.32180288, -0.54167074, 0.20695621, -0.28566203],
#  [1.6736617, 0.5860147, -0.2753636, 1.4817059, 0.41534927],
#  [0.94974893, -0.0071821245, -0.8045455, 0.6121745, 0.7700513],
#  [0.35203728, 0.31559145, -0.7782824, -0.30192336, 0.6812367],
#  [0.5678926, -0.113493, -1.1720062, -0.101761, 0.22246547],
#  [0.6987554, -0.19230586, -0.7736702, -0.026118293, 0.5618282],
#  [0.2981467, 0.21188882, -0.68942297, -0.36952552, 0.016076518],
#  [0.7142323, 0.0705676, -0.6706089, 0.122460425, 0.6445897],
#  [0.9391177, 0.17886648, -0.10550316, -0.25709945, 0.33601993],
#  [0.84414756, 0.89528817, -0.9991682, 0.22476834, 0.73224556],
#  [0.57075715, 0.5555851, -1.5255576, -0.11900461, 1.0259515],
#  [0.99922043, 1.0231079, -0.859612, 1.1248927, 1.1040802],
#  [0.6012774, -0.14736274, -0.08177711, -0.039038837, 0.73441035],
#  [0.9964113, -0.058589198, -1.0399239, 0.11152061, 0.32816616],
#  [0.47189248, 0.41758737, -0.03494177, 0.24283177, 0.5444457],
#  [1.0312464, -0.19321358, -1.0234991, 1.206791, 0.7879381],
#  [0.8091721, 0.5624811, -0.8388165, 1.8201567, 0.66384286],
#  [0.8513308, -0.37794134, -0.59180135, 0.3632121, 0.5573244],
#  [0.2582957, 0.07412021, -1.0666502, 0.21954578, 0.9586144],
#  [0.91970354, 0.89357346, -0.6303806, 0.7876084, 0.65913373],
#  [0.6350912, 0.042012863, -0.47295445, 0.93858534, 1.1554453],
#  [1.0533626, 0.006707117, -1.1013765, 0.6787439, 1.0446566],
#  [1.2485528, 0.6142617, -1.300358, -0.0060922164, 1.2058967],
#  [0.56401926, 0.8958866, -1.8239391, 1.6204942, 0.70646113],
#  [2.144807, 0.89945066, -0.27486086, 1.4986248, 0.60770655],
#  [0.71515685, 0.35509703, -1.4796685, 0.20080243, 0.84398943],
#  [0.4923684, 0.05533127, -0.23663478, -0.2030482, 0.1797934],
#  [0.5746409, 0.23335399, -0.9465582, 0.5515641, 0.2853292],
#  [1.1027464, -0.026341135, -0.39742514, 0.77709246, 0.34235632],
#  [0.88788223, 0.5260467, -0.7389744, 0.8012785, 0.7974686],
#  [2.0131292, 0.6064917, -0.4045433, 1.8112967, 0.42566627],
#  [0.5289884, 0.24416046, -0.3835649, 0.026053078, 0.50619483],
#  [0.823978, -0.011890643, 0.10430786, 0.58855206, 0.6637734],
#  [1.106829, 1.1449162, -0.6516587, 1.3726752, 1.2518703],
#  [1.0712382, 0.7021587, -0.13235046, 1.1943349, 1.169841],
#  [0.8091373, 0.69675654, -0.9081883, 0.86823505, 0.64554006],
#  [0.8539939, 0.63588214, -0.49432614, 0.23839636, 0.41176638],
#  [1.9979163, 1.5168374, -0.34789535, 1.7610909, 0.88490975],
#  [0.27526036, 0.20006594, -0.26061568, 0.34486586, 0.27354372],
#  [0.7084061, 0.27724245, -0.6471653, 0.8041501, 0.4348319],
#  [1.3564959, -0.031654794, -0.845782, 1.112408, 0.82924044],
#  [1.3054467, 0.19052015, -0.68860704, 0.6667327, 0.66549414],
#  [0.4964436, 0.15355994, -0.7910961, 0.4998552, 0.8072022],
#  [0.9614488, 0.1201973, -0.21384619, 1.1350111, 0.52156264],
#  [0.79967344, -0.3853469, -0.35495958, 0.30612037, 0.7662594],
#  [1.7192774, -0.17710678, -0.36293766, 1.1481283, 0.81158453],
#  [0.89723027, 0.16272359, -0.26339707, 0.38677338, 0.5260076],
#  [0.19267367, 0.2417507, -0.28996867, 0.16106412, 0.33210438],
#  [0.50496143, 0.026188442, -0.099804044, 0.29388145, 0.5141292],
#  [0.26874337, 0.012588637, -0.019559493, 0.016973265, 0.28531936],
#  [0.7877631, 0.29367933, -0.36972106, 0.5771625, 0.9991827],
#  [0.37529576, 0.15039122, 0.09659498, -0.08043973, 0.25764132],
#  [0.25005418, -0.16202573, -0.38949782, -0.28327253, 0.04260492],
#  [-0.040054142, -0.18641435, -0.19937266, 0.34351417, 0.36193204],
#  [1.1514328, 0.7192723, -1.0551593, 0.48131233, 0.44738618],
#  [1.0753868, -0.4343204, -0.2682054, 0.831704, 0.601973],
#  [0.8131431, -0.025006378, -0.2785929, 0.015231066, 0.36311042],
#  [1.1554307, -0.18603364, -0.32382807, 1.0594497, 0.75225663],
#  [1.5000595, 0.33552194, -0.31971315, 0.17153795, 0.48722464],
#  [1.2683927, 0.12332104, -0.88139886, 0.28746605, 0.16298716],
#  [0.4114346, 0.7094465, -0.28212103, 0.6854772, 1.1229382],
#  [0.38734534, -0.077104956, -0.32388812, 0.42454594, 0.6927282],
#  [0.9511463, 0.060856674, -0.5199702, 0.23652984, 0.38696694],
#  [0.6482632, -0.18304525, -0.26939434, 0.27028286, 0.4262063],
#  [0.52540207, -0.07465558, -0.6109375, 0.52648944, 0.6395399],
#  [0.50314635, 0.1334523, -0.15363018, -0.0023885705, 0.48293868],
#  [0.8003242, -0.15929317, -0.57372266, 0.775909, 1.129928],
#  [0.51300776, 0.2622921, -0.43306303, 0.010146298, 0.3108857],
#  [0.4917408, 0.081722036, -0.31596574, 0.1155701, 0.59529793],
#  [0.8612207, 0.52470666, -1.093445, 0.5826004, 0.7323583],
#  [0.8984893, -0.13155963, -0.2041601, 0.719378, 0.63488877],
#  [1.8081207, 0.48467356, -0.7060573, 0.113675915, 0.67610985],
#  [0.51108414, 0.1525022, -1.1727086, 0.7459088, 0.6054174],
#  [0.4333413, 0.33585003, -1.0421692, 0.7817458, 0.45986488],
#  [0.24413642, -0.18526842, -0.5189514, 0.015379563, 0.38836756],
#  [0.25186396, -0.045084804, -0.39301223, -0.021797417, 0.10101474],
#  [-0.065790236, 0.12455236, -0.14714973, 0.056355394, 0.24789387],
#  [0.97800124, 0.18984006, -0.42927802, -0.05717814, 0.77248406],
#  [-0.09400312, -0.022492211, -0.11905198, -0.17390375, 0.32538527],
#  [1.4276351, -0.37849092, -1.1720912, -0.103286184, 1.2246082],
#  [0.64330065, 0.38186476, -0.87025374, 1.2707319, 1.034323],
#  [0.4479228, -0.09766696, -0.7467508, 0.09196841, 0.95049804],
#  [0.96933335, -0.19227438, -1.4250966, 0.598109, 0.48129216],
#  [0.96946865, -0.20292091, -1.1574764, 1.1942378, 0.49436933],
#  [0.6813748, -0.3084787, -0.74036187, 0.12060421, 0.74758315],
#  [0.10035116, -0.10645367, -0.26434386, 0.045032546, 0.14704053],
#  [0.32649767, 0.2077149, -0.30119798, 0.19732077, 0.075733334],
#  [0.69643205, -0.16001512, -0.44685432, -0.022558307, 0.5710474],
#  [0.51809937, -0.2002657, -0.450132, 0.13948844, 0.2452668],
#  [0.27564353, 0.41486716, -0.3165217, 0.10739401, 0.39594042],
#  [1.2162843, 0.34550297, -0.5876769, 0.3761578, 0.3607769],
#  [0.5265123, -0.26714423, -0.5795779, 0.4041647, 0.66229284],
#  [0.5620223, -0.14296216, -0.8242746, 0.0767414, 0.21865667],
#  [0.49141628, -0.3133767, -0.17686245, 0.27674875, 0.40786204],
#  [1.1815695, -0.40869308, -0.30053404, 0.5738004, 0.47248104],
#  [0.68153834, 0.39470604, -0.2738119, 0.5958234, 0.48026285],
#  [1.004987, -0.2754514, -0.37680244, 0.6715648, 1.0464942],
#  [0.8159361, -0.31968603, -0.4947105, 0.40273798, 0.49868974],
#  [0.14337538, 0.043739688, -0.23088077, -0.15661436, 0.56125516],
#  [0.35099176, -0.16678806, -0.49428645, -0.22876735, 0.48508066],
#  [0.19381696, -0.42859796, -0.44191, 0.012127799, 0.34820178],
#  [0.14569667, -0.030299094, -0.04070671, -0.1410398, 0.52470964],
#  [0.113537565, -0.07929024, -0.13997838, -0.25780728, 0.21191551],
#  [0.6813439, 0.019441059, -0.27713615, 0.32725272, 0.666589],
#  [1.0743053, 0.20942184, -0.25244763, 0.26978168, 0.758862],
#  [0.36798948, -0.13988715, -0.10882816, 0.24534677, 0.09155384],
#  [0.2741241, -0.10603224, -0.12146494, -0.29974535, 0.34981784],
#  [0.51555365, -0.00416371, -0.18069345, -0.2686597, 0.023232227],
#  [0.37703258, -0.16409898, -0.60511756, -0.07589924, 0.24461879],
#  [0.65881747, 0.42579943, -0.5551849, 0.52947384, 0.6833248],
#  [1.0989591, 0.09992282, -0.6889743, 0.5539743, 0.6168245],
#  [0.33392808, -0.17579974, -0.43093577, 0.049229633, -0.03952892],
#  [0.65404046, -0.11772434, -0.4790688, 0.30920115, 0.52015686],
#  [0.753694, 0.19413227, -0.48574692, 0.8619895, 0.62622494],
#  [0.12898313, 0.069414474, -0.06600135, 0.46449292, 0.4118795],
#  [-0.093852624, -0.2202811, -0.20901816, -0.0634871, 0.34309623],
#  [0.34539378, 0.16870366, -0.11793132, 0.021435123, 0.23727053],
#  [0.34344023, -0.063429505, -0.4760227, 0.14665672, 0.32284757],
#  [0.8371978, -0.4139092, -0.7424931, 0.07996345, 0.55990803],
#  [0.09897789, 0.31770408, -0.27261811, 0.20744476, 0.051328715],
#  [0.09034899, -0.0012872153, -0.25379995, 0.12901098, 0.11343159],
#  [0.07184743, 0.007505347, -0.34021646, 0.14862745, 0.057547487],
#  [0.55298316, -0.23933697, -0.15495846, 0.2638756, 0.43555188],
#  [0.3556934, 0.17328781, -0.22299108, 0.10018472, 0.17886682],
#  [1.7635014, -0.06721246, -1.9060057, 0.4144489, 0.20112889],
#  [0.7510568, 0.46898454, -1.4119635, 0.3493815, 0.84429866],
#  [0.7018959, 0.0631977, -0.28906938, 0.26158017, 0.609303],
#  [0.78179735, 0.08769054, -0.82978636, 0.9490738, 0.5896968],
#  [1.4288517, 0.013460926, -0.52951175, 0.4777621, 0.74138004],
#  [0.6883101, 0.33244863, -0.23990342, 0.13829929, 0.2304996],
#  [0.40419954, -0.105081946, -0.85239697, 0.62300646, 1.0756254],
#  [1.3223239, 0.057732563, -0.7870047, 0.8919723, 0.6192175],
#  [0.58017683, -0.30506006, -0.16036981, 0.65981394, 0.38151136],
#  [0.7373187, 0.30747265, -1.0172619, 0.2754636, 0.36804911],
#  [0.6616522, 0.08434806, -0.29949403, 0.79052526, 0.3950058],
#  [0.46709228, -0.104154214, -0.29179454, -0.54253405, 0.49438214],
#  [1.0309649, -0.3220962, -0.46073735, 0.3677903, 0.52472675],
#  [0.6759523, -0.3695633, -0.7910746, 0.19310884, 1.6251627],
#  [0.87111026, 0.4732458, -1.0002369, 0.029657947, 0.4006332],
#  [0.35328114, 0.0028458573, -0.7672795, 0.3442377, 1.5221974],
#  [0.20219295, 0.1969643, -0.3551783, -0.3195985, 0.7169917],
#  [0.58715504, -0.021963684, -0.24417649, 0.11259465, 0.6140069],
#  [0.27132604, 0.14306389, -0.11059004, 0.2115751, 0.46392792],
#  [1.374684, -0.820588, -1.0447633, 0.38329506, 0.9463387],
#  [0.5252833, 0.013206192, -0.3880632, 0.29075477, 0.55377614],
#  [1.2112423, 0.41697818, -0.7362787, 0.5468046, 0.16276327],
#  [0.64028883, 0.43921372, -0.76688737, -0.13770615, 1.1385111],
#  [0.21508142, 0.035608783, -0.1785259, 0.5289645, 0.3889559],
#  [0.75504273, -0.102696024, -0.36646637, 0.20778446, 0.19903786],
#  [0.41174978, 0.17505619, -0.77089536, -0.0031551488, 0.8254768],
#  [0.3085093, 0.10878258, -0.5630044, 0.54150397, 0.3585847],
#  [0.07143669, -0.14463194, -0.0766974, 0.43978527, 0.43796864],
#  [0.4060306, -0.06457329, -0.15903017, -0.053311814, 0.012690553],
#  [-0.03482555, -0.15975736, -0.17589967, -0.14350425, -0.039999094],
#  [0.6283044, 0.39834803, -0.113139935, -0.08647853, 0.22218047],
#  [1.9824567, 0.017670795, -0.51481456, 0.17456555, 0.2995584],
#  [0.38755673, 0.21732214, -0.49980137, -0.011460103, 0.66262895],
#  [0.68822765, 0.21929649, -0.1292838, -0.28379783, 0.57170916],
#  [0.25925002, 0.08461187, -0.1513251, -0.30652097, 0.060834363],
#  [0.48188758, 0.2648497, -0.48562467, -0.120528914, 0.28653428],
#  [0.2873955, 0.020123564, 0.26408052, -0.3290548, 0.36733034],
#  [0.42634013, 0.09849412, 0.16050702, -0.034794107, 0.088338815],
#  [0.15530157, 0.23158285, 0.09531219, -0.12156467, 0.027150206],
#  [0.35355353, 0.106988646, 0.2026035, -0.07332319, 0.32773107],
#  [1.0256487, -0.06908952, -0.35144633, 0.61936855, 0.26533273],
#  [1.16413, 0.5371597, -1.0109689, 0.41731232, 0.29800737],
#  [0.3815382, 0.104257904, -0.31002358, 0.048822016, 0.29079995],
#  [0.38099307, 0.23976636, -0.26828295, 0.149499, 0.37900263],
#  [0.15315974, 0.20367765, -0.09033254, 0.065069616, 0.27613303],
#  [1.320587, 0.29784095, -0.49505335, 0.46163875, 0.6068275],
#  [0.23645318, 0.13253894, -0.22932163, -0.23109859, 0.20004345],
#  [0.6415043, -0.10290306, -0.5601562, 0.24613197, 0.23604378],
#  [0.7088399, -0.07057385, -0.31155, -0.443531, 0.24316855],
#  [0.2819376, 0.06527317, -0.20451802, -0.34471256, 0.42505056],
#  [0.40776497, -0.034321707, 0.017237978, 0.007236488, 0.19564909],
#  [-0.1172212, -0.1451891, -0.1199407, -0.23203728, 0.07179496],
#  [0.32838285, 0.16022454, -0.15197518, -0.046971947, 0.111158706],
#  [0.5379643, -0.07531366, -0.53560275, 1.074602, 0.64353555],
#  [0.33388302, 0.21329822, -0.36772546, 0.37742582, 0.5559883],
#  [1.3056768, -0.182488, -0.36167368, 0.3588964, 0.8916305],
#  [0.39037097, 0.609198, -0.49859115, 0.46999577, 1.0512084],
#  [0.9740729, 0.33972192, 0.039358936, 1.0077325, 1.0334634],
#  [1.2440137, 0.44761553, -0.39583775, 1.3714341, 1.2943517],
#  [1.1019117, 0.1943909, -1.3148829, 1.316053, 0.91892254],
#  [0.8172267, 0.15603495, -0.64013034, 0.6726042, 0.9583778],
#  [0.97951496, 0.36282745, -0.03343713, 0.78726274, 1.5636051],
#  [0.18747355, 0.42747587, -0.45178428, 0.18923491, 1.038253],
#  [0.6376435, -0.23447868, -0.6933482, 0.13874997, 0.6590757],
#  [0.02803274, 0.30582634, -0.10174809, -0.071452215, 0.2330842],
#  [0.92621195, 0.1456601, -0.660246, 0.4594483, 0.78290516],
#  [0.70063496, 0.2552602, -0.35334194, 0.71624553, 0.4330594],
#  [0.37105852, -0.14374019, -0.19397232, 0.03622094, 0.17177701],
#  [1.1926798, 0.24548809, -0.7167975, 0.22843532, 0.8993787],
#  [0.18668605, 0.6188671, -0.5107594, -0.06854274, 0.45374656],
#  [0.6677798, 0.268696, -1.5688409, 1.3287991, 1.0556211],
#  [0.39399123, 0.09025708, -0.92714745, -0.32350656, 0.55560493],
#  [0.95444286, 0.54329544, -1.1222937, 0.76013136, 0.46368],
#  [0.4475615, 0.32518372, -1.1419733, 0.6063139, 0.8703473],
#  [0.8575188, -0.52372956, -1.4668897, -0.16251865, 1.3265554],
#  ...]

# %%
split_df = pd.DataFrame(vectors, columns=['v1', 'v2', 'v3','v4',"v5"])
result_doc = book_df.join(split_df, how='left')

# %%
result_doc
# Out:
#                          Names  Average_rating  Read_by  Year  \
# 0                     Гиперион            8.68     9259  1989
# 1                     Гиперион            8.68     9259  1989
# 2                     Гиперион            8.68     9259  1989
# 3                     Гиперион            8.68     9259  1989
# 4                     Гиперион            8.68     9259  1989
# ...                        ...             ...      ...   ...
# 16850           Чёрный спецназ            6.68       87  2007
# 16851  Планета по имени Тигрис            7.48       31  1984
# 16852           Пульт мертвеца            6.90       75  1988
# 16853          Зелёные и серые            6.23       34  2004
# 16854          Зелёные и серые            6.23       34  2004
#
#                                                   Review  Score  \
# 0      \nТот, кто будет читать этот роман как жанрову...     10
# 1      \nНи за что бы не сел за написание отзыва к эт...      2
# 2      \nДаа, а я уж думал, что я старый, умудренный ...     10
# 3      \nНаверное, после «Гипериона» читать что-то ещ...     10
# 4      \nРоман мне не понравился. С научной фантастик...      6
# ...                                                  ...    ...
# 16850  \nСовсем не впечатлило. Там, где автор старает...      6
# 16851  \nЭто книга из серии «Детская литература». Пос...      6
# 16852  \nне асилил. Брал после Черного Спецназа, кото...      5
# 16853  \nКнига, в достаточной степени серая, но не со...      5
# 16854  \nПримитивная и пустая пьеса о жизни зеленых и...      2
#
#                                                     Text  \
# 0      тот кто будет читать этот роман как жанровую ф...
# 1      ни за что бы не сел за написание отзыва к этой...
# 2      даа а я уж думал что я старый умудренный жизне...
# 3      наверное после гипериона читать что то еще в ж...
# 4      роман мне не понравился с научной фантастикой ...
# ...                                                  ...
# 16850  совсем не впечатлило там где автор старается б...
# 16851  это книга из серии детская литература после ше...
# 16852  не асилил брал после черного спецназа который ...
# 16853  книга в достаточной степени серая но не совсем...
# 16854  примитивная и пустая пьеса о жизни зеленых и с...
#
#                                                   Lemmas        v1        v2  \
# 0      [читать, роман, жанровый, фантастика, разочаро...  1.215935 -1.016979
# 1      [сесть, написание, отзыв, книга, зашкаливать, ...  0.537782  0.090149
# 2      [даа, думать, старый, умудрить, жизненный, опы...  0.947796  0.176686
# 3      [наверное, гиперион, читать, ещё, жанр, фантас...  0.164911  0.484861
# 4      [роман, понравиться, научный, фантастика, знак...  0.499530 -0.052848
# ...                                                  ...       ...       ...
# 16850  [впечатлить, автор, стараться, серьёзный, полу...  0.298671  0.090788
# 16851  [это, книга, серия, детский, литература, шедев...  0.391004  0.121411
# 16852  [асилила, брать, чёрный, спецназ, который, заг...  0.436677 -0.088816
# 16853  [книга, достаточный, степень, серый, тоска, зе...  0.782613 -0.510657
# 16854  [примитивный, пустой, пьеса, жизнь, зелёный, с...  0.512077 -0.139103
#
#              v3        v4        v5
# 0     -0.575611  0.836315  0.448552
# 1     -0.665917  1.465397  1.055246
# 2     -0.788030 -0.108543  0.098518
# 3     -0.512670 -0.103833  0.565418
# 4     -0.442487  0.214121  0.394439
# ...         ...       ...       ...
# 16850 -0.061660 -0.214491  0.466201
# 16851 -0.131032 -0.078306  0.211680
# 16852 -0.163576  0.064618  0.153134
# 16853 -0.458470 -0.046452  0.301033
# 16854 -0.493439  0.061017  0.375914
#
# [16855 rows x 13 columns]

# %%
# Модель регресии

x = result_doc.drop(["Names", "Review", "Score", "Text", "Lemmas"],axis=1).values

y = result_doc["Score"].values

# %%
# Стандартизация переменных

sc = StandardScaler()
x_train, x_test, y_train, y_test = train_test_split(sc.fit_transform(x), y, test_size=0.4)

# %%
model2 = LogisticRegression(random_state = 50).fit(x_train, y_train)

# %%
y_preds = model2.predict(x_test)

# %%
mean_absolute_error(y_test, y_preds)
# Out:
# 1.4906555918125186

# %%
accuracy_score(y_test, y_preds)
# Out:
# 0.2607534856125779

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        77
#            2       0.00      0.00      0.00        94
#            3       0.00      0.00      0.00       136
#            4       0.00      0.00      0.00       207
#            5       0.33      0.00      0.00       447
#            6       0.22      0.13      0.16       881
#            7       0.09      0.00      0.00      1046
#            8       0.26      0.75      0.38      1636
#            9       0.30      0.02      0.03      1134
#           10       0.30      0.36      0.32      1084
#
#     accuracy                           0.26      6742
#    macro avg       0.15      0.13      0.09      6742
# weighted avg       0.22      0.26      0.17      6742
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X = tfidf.fit_transform(book_df.Review)

# %%
Y = book_df.Score

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.4)

# %%
model3 = LogisticRegression(random_state = 50).fit(x_train, y_train)
# Out:
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_preds = model3.predict(x_test)

# %%
mean_absolute_error(y_test, y_preds)
# Out:
# 1.399881340848413

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        74
#            2       0.00      0.00      0.00        83
#            3       0.00      0.00      0.00       158
#            4       0.00      0.00      0.00       202
#            5       0.10      0.00      0.00       421
#            6       0.29      0.13      0.18       862
#            7       0.22      0.12      0.15      1023
#            8       0.28      0.69      0.40      1719
#            9       0.23      0.12      0.16      1126
#           10       0.37      0.33      0.35      1074
#
#     accuracy                           0.28      6742
#    macro avg       0.15      0.14      0.12      6742
# weighted avg       0.25      0.28      0.23      6742
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\marus\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### свои отзывы

# %%
otzyv_mean = input('Средний балл:')
otzyv_popular = input('Число читателей: ')
otzyv_year = input('Год: ')
otzyv = input('Введите ваш отзыв:')
otzyv_response(otzyv)
# Out:
# Средний балл:0
# Число читателей: 1
# Год: 2

# %%
def otzyv_response(otzyv):
    new_df = pd.DataFrame([[0,1,2,3]],columns=['Rating', 'Popularity', 'Year', 'Review'])
    new_df['Rating'] = otzyv_mean
    new_df['Popularity'] = otzyv_popular
    new_df['Year'] = otzyv_year
    new_df['Review'] = otzyv

    new_df["Text"] = new_df.Review.str.lower()
    english = (r'[a-z]+')
    digits = (r'\d+')
    punctuation = (r'[^\w\s]')
    extra_spaces = (r'\s{2,}')

    new_df.Text = new_df.Text.str.replace(english, ' ')
    new_df.Text = new_df.Text.str.replace(digits, ' ')
    new_df.Text = new_df.Text.str.replace(punctuation, ' ')
    new_df.Text = new_df.Text.str.replace(extra_spaces, ' ')

    new_lemmas = []

    for sentence in new_df.Text:
        sent = list(sentence.split())
        sen = []
        for word in sent:
            lemma = morph.parse(word)[0].normal_form
            sen.append(lemma)
        new_lemmas.append(sen)

    new_df['Lemma'] = new_lemmas

    new_df.Lemma = new_df.Lemma.apply(lambda x: [item for item in x if item not in russian_stopwords])

    new_text = list(new_df.Lemma.values)
    new_docs = [TaggedDocument(doc, [i]) for i, doc in enumerate(new_text)]
    new_vec = model_doc[new_docs[0].tags[0]]

    new_split_df = pd.DataFrame([new_vec], columns=['v1', 'v2', 'v3','v4',"v5"])
    new_df = new_df.join(new_split_df, how='left')

    z = new_df.drop(['Review', 'Text', 'Lemma'], axis = 1).values

    otzyv_prediction = model2.predict(z)

    if otzyv_prediction[0] == 1:
        maybe = '5 и ниже'
        print('Предлагаемая оценка отзыва - ', otzyv_prediction[0], ', что соответствует рейтингу ', maybe, '.', sep = '')
    else:
        print('Предлагаемая оценка отзыва - ', otzyv_prediction[0], '.', sep = '')
# Out:
# C:\Users\marus\AppData\Local\Temp/ipykernel_12416/2675778089.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df.Text = new_df.Text.str.replace(english, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_12416/2675778089.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df.Text = new_df.Text.str.replace(digits, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_12416/2675778089.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df.Text = new_df.Text.str.replace(punctuation, ' ')
# C:\Users\marus\AppData\Local\Temp/ipykernel_12416/2675778089.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df.Text = new_df.Text.str.replace(extra_spaces, ' ')

# %%
new_df
# Out:
#   Rating Popularity Year Review Text
# 0      0          1    2      4
